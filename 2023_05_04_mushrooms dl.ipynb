# %%
import warnings

warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
mushroom = pd.read_csv("C:/Users/진현킴/Downloads/mushrooms.csv")

# %%
mushroom
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         n          k  ...                        s
# 1               c         b          k  ...                        s
# 2               c         b          n  ...                        s
# 3               c         n          n  ...                        s
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# ...          ...       ...               ...        ...     ...
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for i in mushroom.columns :
    mushroom[i] = le.fit_transform(mushroom[i])

# %%
mushroom
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# 2                   1             0          0           5  ...
# 3                   1             0          1           5  ...
# 4                   1             1          0           4  ...
# ...               ...           ...        ...         ...  ...
# 8119                0             0          0          11  ...
# 8120                0             0          0          11  ...
# 8121                0             0          0           5  ...
# 8122                1             0          1           0  ...
# 8123                0             0          0          11  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                            2                       7
# 1                            2                       7
# 2                            2                       7
# 3                            2                       7
# 4                            2                       7
# ...                        ...                     ...
# 8119                         2                       5
# 8120                         2                       5
# 8121                         2                       5
# 8122                         1                       7
# 8123                         2                       5
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                          7          0           2            1          4
# 1                          7          0           2            1          4
# 2                          7          0           2            1          4
# 3                          7          0           2            1          4
# 4                          7          0           2            1          0
# ...                      ...        ...         ...          ...        ...
# 8119                       5          0           1            1          4
# 8120                       5          0           0            1          4
# 8121                       5          0           1            1          4
# 8122                       7          0           2            1          0
# 8123                       5          0           1            1          4
#
#       spore-print-color  population  habitat
# 0                     2           3        5
# 1                     3           2        1
# 2                     3           2        3
# 3                     2           3        5
# 4                     3           0        1
# ...                 ...         ...      ...
# 8119                  0           1        2
# 8120                  0           4        2
# 8121                  0           1        2
# 8122                  7           4        2
# 8123                  4           1        2
#
# [8124 rows x 23 columns]

# %%
y = mushroom['class']

y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int32

# %%
X = mushroom.iloc[:,0:22].values

from sklearn.preprocessing import LabelEncoder
## from keras.utils import to_categorical

encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
## y_one_hot = to_categorical(y_encoded, num_classes=2)
Y = pd.get_dummies(y_encoded).values

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
X
# Out:
# array([[1, 5, 2, ..., 4, 2, 3],
#        [0, 5, 2, ..., 4, 3, 2],
#        [0, 0, 2, ..., 4, 3, 2],
#        ...,
#        [0, 2, 2, ..., 4, 0, 1],
#        [1, 3, 3, ..., 0, 7, 4],
#        [0, 5, 2, ..., 4, 4, 1]])

# %%
Y
# Out:
# array([[0, 1],
#        [1, 0],
#        [1, 0],
#        ...,
#        [1, 0],
#        [0, 1],
#        [1, 0]], dtype=uint8)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (6499, 2)
# (1625, 2)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD, Adam


model = Sequential()

model.add(Dense(10,input_shape=(22,),activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(2,activation='sigmoid'))

model.compile(Adam(lr=0.0001),'binary_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dense_1 (Dense)             (None, 8)                 88
#
#  dense_2 (Dense)             (None, 6)                 54
#
#  dense_3 (Dense)             (None, 2)                 14
#
# =================================================================
# Total params: 386
# Trainable params: 386
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model_history=model.fit(x = X_train, y = y_train, epochs=100, batch_size=32, validation_data = (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test, axis=1)
y_pred_class = np.argmax(y_pred, axis=1)
# Out:
# Epoch 1/100
# 204/204 [==============================] - 2s 5ms/step - loss: 0.6906 - accuracy: 0.4281 - val_loss: 0.6795 - val_accuracy: 0.4578
# Epoch 2/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.6655 - accuracy: 0.5987 - val_loss: 0.6501 - val_accuracy: 0.6671
# Epoch 3/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.6339 - accuracy: 0.6972 - val_loss: 0.6148 - val_accuracy: 0.7526
# Epoch 4/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.5995 - accuracy: 0.7769 - val_loss: 0.5808 - val_accuracy: 0.8234
# Epoch 5/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.5649 - accuracy: 0.8383 - val_loss: 0.5448 - val_accuracy: 0.8825
# Epoch 6/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.5280 - accuracy: 0.8912 - val_loss: 0.5075 - val_accuracy: 0.9120
# Epoch 7/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.4922 - accuracy: 0.9220 - val_loss: 0.4732 - val_accuracy: 0.9280
# Epoch 8/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.4587 - accuracy: 0.9371 - val_loss: 0.4412 - val_accuracy: 0.9446
# Epoch 9/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.4273 - accuracy: 0.9486 - val_loss: 0.4108 - val_accuracy: 0.9502
# Epoch 10/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3969 - accuracy: 0.9563 - val_loss: 0.3814 - val_accuracy: 0.9557
# Epoch 11/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3673 - accuracy: 0.9601 - val_loss: 0.3524 - val_accuracy: 0.9594
# Epoch 12/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.9635 - val_loss: 0.3229 - val_accuracy: 0.9618
# Epoch 13/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3055 - accuracy: 0.9671 - val_loss: 0.2872 - val_accuracy: 0.9662
# Epoch 14/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2657 - accuracy: 0.9694 - val_loss: 0.2435 - val_accuracy: 0.9705
# Epoch 15/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2199 - accuracy: 0.9741 - val_loss: 0.1964 - val_accuracy: 0.9729
# Epoch 16/100
# 204/204 [==============================] - 1s 3ms/step - loss: 0.1721 - accuracy: 0.9808 - val_loss: 0.1494 - val_accuracy: 0.9822
# Epoch 17/100
# 204/204 [==============================] - 1s 3ms/step - loss: 0.1299 - accuracy: 0.9878 - val_loss: 0.1123 - val_accuracy: 0.9895
# Epoch 18/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0992 - accuracy: 0.9935 - val_loss: 0.0867 - val_accuracy: 0.9951
# Epoch 19/100
# 204/204 [==============================] - 1s 3ms/step - loss: 0.0781 - accuracy: 0.9958 - val_loss: 0.0686 - val_accuracy: 0.9969
# Epoch 20/100
# 204/204 [==============================] - 1s 2ms/step - loss: 0.0628 - accuracy: 0.9974 - val_loss: 0.0551 - val_accuracy: 0.9988
# Epoch 21/100
# 204/204 [==============================] - 1s 3ms/step - loss: 0.0512 - accuracy: 0.9980 - val_loss: 0.0449 - val_accuracy: 0.9988
# Epoch 22/100
# 204/204 [==============================] - 1s 3ms/step - loss: 0.0421 - accuracy: 0.9988 - val_loss: 0.0368 - val_accuracy: 0.9988
# Epoch 23/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 0.9989 - val_loss: 0.0304 - val_accuracy: 0.9988
# Epoch 24/100
# 204/204 [==============================] - 1s 3ms/step - loss: 0.0289 - accuracy: 0.9991 - val_loss: 0.0252 - val_accuracy: 0.9988
# Epoch 25/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 0.9994 - val_loss: 0.0207 - val_accuracy: 0.9988
# Epoch 26/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 0.9995 - val_loss: 0.0169 - val_accuracy: 0.9994
# Epoch 27/100
# 204/204 [==============================] - 1s 2ms/step - loss: 0.0158 - accuracy: 0.9997 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 28/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 29/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 30/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 31/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 32/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 33/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 34/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 35/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 36/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 37/100
# 204/204 [==============================] - 1s 3ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 38/100
# 204/204 [==============================] - 1s 3ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 39/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 40/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 41/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 42/100
# 204/204 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 43/100
# 204/204 [==============================] - 0s 2ms/step - loss: 9.9028e-04 - accuracy: 1.0000 - val_loss: 9.0723e-04 - val_accuracy: 1.0000
# Epoch 44/100
# 204/204 [==============================] - 0s 2ms/step - loss: 8.5665e-04 - accuracy: 1.0000 - val_loss: 7.8556e-04 - val_accuracy: 1.0000
# Epoch 45/100
# 204/204 [==============================] - 0s 2ms/step - loss: 7.4156e-04 - accuracy: 1.0000 - val_loss: 6.8156e-04 - val_accuracy: 1.0000
# Epoch 46/100
# 204/204 [==============================] - 0s 2ms/step - loss: 6.4270e-04 - accuracy: 1.0000 - val_loss: 5.9136e-04 - val_accuracy: 1.0000
# Epoch 47/100
# 204/204 [==============================] - 0s 2ms/step - loss: 5.5807e-04 - accuracy: 1.0000 - val_loss: 5.1420e-04 - val_accuracy: 1.0000
# Epoch 48/100
# 204/204 [==============================] - 0s 2ms/step - loss: 4.8490e-04 - accuracy: 1.0000 - val_loss: 4.4658e-04 - val_accuracy: 1.0000
# Epoch 49/100
# 204/204 [==============================] - 0s 2ms/step - loss: 4.2188e-04 - accuracy: 1.0000 - val_loss: 3.8956e-04 - val_accuracy: 1.0000
# Epoch 50/100
# 204/204 [==============================] - 0s 2ms/step - loss: 3.6733e-04 - accuracy: 1.0000 - val_loss: 3.3906e-04 - val_accuracy: 1.0000
# Epoch 51/100
# 204/204 [==============================] - 1s 3ms/step - loss: 3.2027e-04 - accuracy: 1.0000 - val_loss: 2.9579e-04 - val_accuracy: 1.0000
# Epoch 52/100
# 204/204 [==============================] - 0s 2ms/step - loss: 2.7918e-04 - accuracy: 1.0000 - val_loss: 2.5787e-04 - val_accuracy: 1.0000
# Epoch 53/100
# 204/204 [==============================] - 0s 2ms/step - loss: 2.4404e-04 - accuracy: 1.0000 - val_loss: 2.2523e-04 - val_accuracy: 1.0000
# Epoch 54/100
# 204/204 [==============================] - 1s 3ms/step - loss: 2.1303e-04 - accuracy: 1.0000 - val_loss: 1.9688e-04 - val_accuracy: 1.0000
# Epoch 55/100
# 204/204 [==============================] - 1s 3ms/step - loss: 1.8631e-04 - accuracy: 1.0000 - val_loss: 1.7210e-04 - val_accuracy: 1.0000
# Epoch 56/100
# 204/204 [==============================] - 1s 2ms/step - loss: 1.6321e-04 - accuracy: 1.0000 - val_loss: 1.5083e-04 - val_accuracy: 1.0000
# Epoch 57/100
# 204/204 [==============================] - 0s 2ms/step - loss: 1.4294e-04 - accuracy: 1.0000 - val_loss: 1.3236e-04 - val_accuracy: 1.0000
# Epoch 58/100
# 204/204 [==============================] - 1s 3ms/step - loss: 1.2538e-04 - accuracy: 1.0000 - val_loss: 1.1595e-04 - val_accuracy: 1.0000
# Epoch 59/100
# 204/204 [==============================] - 0s 2ms/step - loss: 1.0988e-04 - accuracy: 1.0000 - val_loss: 1.0165e-04 - val_accuracy: 1.0000
# Epoch 60/100
# 204/204 [==============================] - 0s 2ms/step - loss: 9.6461e-05 - accuracy: 1.0000 - val_loss: 8.9228e-05 - val_accuracy: 1.0000
# Epoch 61/100
# 204/204 [==============================] - 1s 3ms/step - loss: 8.4745e-05 - accuracy: 1.0000 - val_loss: 7.8314e-05 - val_accuracy: 1.0000
# Epoch 62/100
# 204/204 [==============================] - 1s 3ms/step - loss: 7.4337e-05 - accuracy: 1.0000 - val_loss: 6.8775e-05 - val_accuracy: 1.0000
# Epoch 63/100
# 204/204 [==============================] - 0s 2ms/step - loss: 6.5369e-05 - accuracy: 1.0000 - val_loss: 6.0422e-05 - val_accuracy: 1.0000
# Epoch 64/100
# 204/204 [==============================] - 0s 2ms/step - loss: 5.7480e-05 - accuracy: 1.0000 - val_loss: 5.3145e-05 - val_accuracy: 1.0000
# Epoch 65/100
# 204/204 [==============================] - 0s 2ms/step - loss: 5.0545e-05 - accuracy: 1.0000 - val_loss: 4.6697e-05 - val_accuracy: 1.0000
# Epoch 66/100
# 204/204 [==============================] - 0s 2ms/step - loss: 4.4436e-05 - accuracy: 1.0000 - val_loss: 4.1003e-05 - val_accuracy: 1.0000
# Epoch 67/100
# 204/204 [==============================] - 0s 2ms/step - loss: 3.9100e-05 - accuracy: 1.0000 - val_loss: 3.6089e-05 - val_accuracy: 1.0000
# Epoch 68/100
# 204/204 [==============================] - 0s 2ms/step - loss: 3.4443e-05 - accuracy: 1.0000 - val_loss: 3.1744e-05 - val_accuracy: 1.0000
# Epoch 69/100
# 204/204 [==============================] - 1s 3ms/step - loss: 3.0345e-05 - accuracy: 1.0000 - val_loss: 2.7944e-05 - val_accuracy: 1.0000
# Epoch 70/100
# 204/204 [==============================] - 1s 3ms/step - loss: 2.6742e-05 - accuracy: 1.0000 - val_loss: 2.4611e-05 - val_accuracy: 1.0000
# Epoch 71/100
# 204/204 [==============================] - 1s 3ms/step - loss: 2.3583e-05 - accuracy: 1.0000 - val_loss: 2.1688e-05 - val_accuracy: 1.0000
# Epoch 72/100
# 204/204 [==============================] - 1s 3ms/step - loss: 2.0811e-05 - accuracy: 1.0000 - val_loss: 1.9138e-05 - val_accuracy: 1.0000
# Epoch 73/100
# 204/204 [==============================] - 1s 3ms/step - loss: 1.8354e-05 - accuracy: 1.0000 - val_loss: 1.6878e-05 - val_accuracy: 1.0000
# Epoch 74/100
# 204/204 [==============================] - 1s 3ms/step - loss: 1.6218e-05 - accuracy: 1.0000 - val_loss: 1.4907e-05 - val_accuracy: 1.0000
# Epoch 75/100
# 204/204 [==============================] - 1s 3ms/step - loss: 1.4317e-05 - accuracy: 1.0000 - val_loss: 1.3159e-05 - val_accuracy: 1.0000
# Epoch 76/100
# 204/204 [==============================] - 0s 2ms/step - loss: 1.2658e-05 - accuracy: 1.0000 - val_loss: 1.1618e-05 - val_accuracy: 1.0000
# Epoch 77/100
# 204/204 [==============================] - 0s 2ms/step - loss: 1.1195e-05 - accuracy: 1.0000 - val_loss: 1.0267e-05 - val_accuracy: 1.0000
# Epoch 78/100
# 204/204 [==============================] - 0s 2ms/step - loss: 9.9007e-06 - accuracy: 1.0000 - val_loss: 9.0865e-06 - val_accuracy: 1.0000
# Epoch 79/100
# 204/204 [==============================] - 0s 2ms/step - loss: 8.7580e-06 - accuracy: 1.0000 - val_loss: 8.0287e-06 - val_accuracy: 1.0000
# Epoch 80/100
# 204/204 [==============================] - 1s 3ms/step - loss: 7.7510e-06 - accuracy: 1.0000 - val_loss: 7.1057e-06 - val_accuracy: 1.0000
# Epoch 81/100
# 204/204 [==============================] - 0s 2ms/step - loss: 6.8557e-06 - accuracy: 1.0000 - val_loss: 6.2954e-06 - val_accuracy: 1.0000
# Epoch 82/100
# 204/204 [==============================] - 0s 2ms/step - loss: 6.0655e-06 - accuracy: 1.0000 - val_loss: 5.5598e-06 - val_accuracy: 1.0000
# Epoch 83/100
# 204/204 [==============================] - 0s 2ms/step - loss: 5.3643e-06 - accuracy: 1.0000 - val_loss: 4.9219e-06 - val_accuracy: 1.0000
# Epoch 84/100
# 204/204 [==============================] - 0s 2ms/step - loss: 4.7461e-06 - accuracy: 1.0000 - val_loss: 4.3567e-06 - val_accuracy: 1.0000
# Epoch 85/100
# 204/204 [==============================] - 0s 2ms/step - loss: 4.2004e-06 - accuracy: 1.0000 - val_loss: 3.8588e-06 - val_accuracy: 1.0000
# Epoch 86/100
# 204/204 [==============================] - 0s 2ms/step - loss: 3.7144e-06 - accuracy: 1.0000 - val_loss: 3.4126e-06 - val_accuracy: 1.0000
# Epoch 87/100
# 204/204 [==============================] - 1s 4ms/step - loss: 3.2909e-06 - accuracy: 1.0000 - val_loss: 3.0220e-06 - val_accuracy: 1.0000
# Epoch 88/100
# 204/204 [==============================] - 1s 4ms/step - loss: 2.9132e-06 - accuracy: 1.0000 - val_loss: 2.6762e-06 - val_accuracy: 1.0000
# Epoch 89/100
# 204/204 [==============================] - 1s 3ms/step - loss: 2.5791e-06 - accuracy: 1.0000 - val_loss: 2.3699e-06 - val_accuracy: 1.0000
# Epoch 90/100
# 204/204 [==============================] - 1s 3ms/step - loss: 2.2852e-06 - accuracy: 1.0000 - val_loss: 2.1001e-06 - val_accuracy: 1.0000
# Epoch 91/100
# 204/204 [==============================] - 1s 3ms/step - loss: 2.0242e-06 - accuracy: 1.0000 - val_loss: 1.8621e-06 - val_accuracy: 1.0000
# Epoch 92/100
# 204/204 [==============================] - 1s 3ms/step - loss: 1.7934e-06 - accuracy: 1.0000 - val_loss: 1.6499e-06 - val_accuracy: 1.0000
# Epoch 93/100
# 204/204 [==============================] - 1s 2ms/step - loss: 1.5893e-06 - accuracy: 1.0000 - val_loss: 1.4624e-06 - val_accuracy: 1.0000
# Epoch 94/100
# 204/204 [==============================] - 1s 3ms/step - loss: 1.4091e-06 - accuracy: 1.0000 - val_loss: 1.2965e-06 - val_accuracy: 1.0000
# Epoch 95/100
# 204/204 [==============================] - 1s 4ms/step - loss: 1.2496e-06 - accuracy: 1.0000 - val_loss: 1.1507e-06 - val_accuracy: 1.0000
# Epoch 96/100
# 204/204 [==============================] - 1s 4ms/step - loss: 1.1092e-06 - accuracy: 1.0000 - val_loss: 1.0225e-06 - val_accuracy: 1.0000
# Epoch 97/100
# 194/204 [===========================>..] - ETA: 0s - loss: 9.6191e-07 - accuracy: 1.0000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = model_history.history['accuracy']
val_acc = model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
