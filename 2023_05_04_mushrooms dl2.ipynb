# %%
import warnings

warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
mushroom = pd.read_csv("C:/Users/진현킴/Downloads/mushrooms.csv")

# %%
mushroom
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         n          k  ...                        s
# 1               c         b          k  ...                        s
# 2               c         b          n  ...                        s
# 3               c         n          n  ...                        s
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# ...          ...       ...               ...        ...     ...
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for i in mushroom.columns :
    mushroom[i] = le.fit_transform(mushroom[i])

# %%
mushroom
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# 2                   1             0          0           5  ...
# 3                   1             0          1           5  ...
# 4                   1             1          0           4  ...
# ...               ...           ...        ...         ...  ...
# 8119                0             0          0          11  ...
# 8120                0             0          0          11  ...
# 8121                0             0          0           5  ...
# 8122                1             0          1           0  ...
# 8123                0             0          0          11  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                            2                       7
# 1                            2                       7
# 2                            2                       7
# 3                            2                       7
# 4                            2                       7
# ...                        ...                     ...
# 8119                         2                       5
# 8120                         2                       5
# 8121                         2                       5
# 8122                         1                       7
# 8123                         2                       5
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                          7          0           2            1          4
# 1                          7          0           2            1          4
# 2                          7          0           2            1          4
# 3                          7          0           2            1          4
# 4                          7          0           2            1          0
# ...                      ...        ...         ...          ...        ...
# 8119                       5          0           1            1          4
# 8120                       5          0           0            1          4
# 8121                       5          0           1            1          4
# 8122                       7          0           2            1          0
# 8123                       5          0           1            1          4
#
#       spore-print-color  population  habitat
# 0                     2           3        5
# 1                     3           2        1
# 2                     3           2        3
# 3                     2           3        5
# 4                     3           0        1
# ...                 ...         ...      ...
# 8119                  0           1        2
# 8120                  0           4        2
# 8121                  0           1        2
# 8122                  7           4        2
# 8123                  4           1        2
#
# [8124 rows x 23 columns]

# %%
y = mushroom['class']

y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int32

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=42)

# %%
import numpy as np

mean = np.mean(X_train, axis = 0)

std = np.std(X_train, axis = 0)

X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

# %%
print(np.any(np.isnan(X_train)))
print(np.any(np.isnan(X_test)))
print(np.any(np.isinf(X_train)))
print(np.any(np.isinf(X_test)))
# Out:
# True
# True
# False
# False

# %%
X_train = pd.DataFrame(X_train).fillna(0).values
X_test = pd.DataFrame(X_test).fillna(0).values

# %%
print(np.any(np.isnan(X_train)))
print(np.any(np.isnan(X_test)))
print(np.any(np.isinf(X_train)))
print(np.any(np.isinf(X_test)))
# Out:
# False
# False
# False
# False

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(64, activation = 'relu', input_shape = (22,)))
model.add(Dropout(0.5))
model.add(Dense(32, activation = 'tanh'))
model.add(Dropout(0.5))
model.add(Dense(2, activation = 'softmax')) 

model.compile(optimizer = 'rmsprop', loss='mse', metrics = ['mse'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 64)                1472
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 3,618
# Trainable params: 3,618
# Non-trainable params: 0
# _________________________________________________________________

# %%
N_EPOCHS = 100
history = model.fit(X_train, y_train, epochs = N_EPOCHS, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2899 - mse: 0.2899 - val_loss: 0.2503 - val_mse: 0.2503
# Epoch 2/100
# 191/191 [==============================] - 0s 2ms/step - loss: 0.2553 - mse: 0.2553 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 3/100
# 191/191 [==============================] - 0s 2ms/step - loss: 0.2502 - mse: 0.2502 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 4/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 5/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 6/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 7/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 8/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 9/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 10/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 11/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 12/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 13/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 14/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 15/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 16/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 17/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 18/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 19/100
# 191/191 [==============================] - 0s 2ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 20/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 21/100
# 191/191 [==============================] - 0s 2ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 22/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 23/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 24/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 25/100
# 191/191 [==============================] - 0s 2ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 26/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 27/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 28/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 29/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 30/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 31/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 32/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 33/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 34/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 35/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 36/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 37/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 38/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 39/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 40/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 41/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 42/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 43/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 44/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 45/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 46/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 47/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 48/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 49/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 50/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 51/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 52/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 53/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 54/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 55/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 56/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 57/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 58/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 59/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 60/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 61/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 62/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 63/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 64/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 65/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 66/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 67/100
# 191/191 [==============================] - 0s 2ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 68/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 69/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 70/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 71/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 72/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 73/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 74/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 75/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 76/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 77/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 78/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 79/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 80/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 81/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 82/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 83/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 84/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 85/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 86/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 87/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 88/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 89/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 90/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 91/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 92/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 93/100
# 191/191 [==============================] - 0s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 94/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 95/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 96/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 97/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 98/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 99/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500
# Epoch 100/100
# 191/191 [==============================] - 1s 3ms/step - loss: 0.2500 - mse: 0.2500 - val_loss: 0.2500 - val_mse: 0.2500

# %%
plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), history.history['loss'], label='train loss')
plt.plot(range(N_EPOCHS), history.history['val_loss'], label='test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
