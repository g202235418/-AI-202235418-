# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from sklearn.datasets import load_linnerud

linnerud = load_linnerud()
print(linnerud.DESCR)
# Out:
# .. _linnerrud_dataset:
#
# Linnerrud dataset
# -----------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20
#     :Number of Attributes: 3
#     :Missing Attribute Values: None
#
# The Linnerud dataset is a multi-output regression dataset. It consists of three
# exercise (data) and three physiological (target) variables collected from
# twenty middle-aged men in a fitness club:
#
# - *physiological* - CSV containing 20 observations on 3 physiological variables:
#    Weight, Waist and Pulse.
# - *exercise* - CSV containing 20 observations on 3 exercise variables:
#    Chins, Situps and Jumps.
#
# .. topic:: References
#
#   * Tenenhaus, M. (1998). La regression PLS: theorie et pratique. Paris:
#     Editions Technic.

# %%
data = pd.concat([pd.DataFrame(linnerud.data, columns=linnerud.feature_names),
                pd.DataFrame(linnerud.target, columns=linnerud.target_names)],
               axis=1)
data.tail()
# Out:
#     Chins  Situps  Jumps  Weight  Waist  Pulse
# 15   12.0   210.0  120.0   202.0   37.0   62.0
# 16    4.0    60.0   25.0   176.0   37.0   54.0
# 17   11.0   230.0   80.0   157.0   32.0   52.0
# 18   15.0   225.0   73.0   156.0   33.0   54.0
# 19    2.0   110.0   43.0   138.0   33.0   68.0

# %%
#상관 관계 행렬
df_corr=data.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %%
x_data=data.loc[:, ['Situps', 'Chins','Jumps']]
y_data=data.loc[:, 'Pulse']
from sklearn.preprocessing import LabelEncoder
## from keras.utils import to_categorical

encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y_data)
## y_one_hot = to_categorical(y_encoded, num_classes=2)
Y = pd.get_dummies(y_encoded).values

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_data, Y, test_size=0.2, random_state=0)

# %%
import numpy as np

mean = np.mean(X_train, axis = 0)

std = np.std(X_train, axis = 0)

X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

# %%
print(np.any(np.isnan(X_train)))
print(np.any(np.isnan(X_test)))
print(np.any(np.isinf(X_train)))
print(np.any(np.isinf(X_test)))
# Out:
# False
# False
# False
# False

# %%
X_train = pd.DataFrame(X_train).fillna(0).values
X_test = pd.DataFrame(X_test).fillna(0).values

# %%
print(np.any(np.isnan(X_train)))
print(np.any(np.isnan(X_test)))
print(np.any(np.isinf(X_train)))
print(np.any(np.isinf(X_test)))
# Out:
# False
# False
# False
# False

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(32, activation = 'relu', input_shape = (3,)))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(1, activation = 'softmax')) 

model.compile(optimizer = 'rmsprop', loss='mse', metrics = ['mse'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 32)                128
#
#  dense_4 (Dense)             (None, 16)                528
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 673
# Trainable params: 673
# Non-trainable params: 0
# _________________________________________________________________

# %%
N_EPOCHS = 100
history = model.fit(X_train, y_train, epochs = N_EPOCHS, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 624ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 2/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 3/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 4/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 5/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 6/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 7/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 8/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 9/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 10/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 11/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 12/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 13/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 14/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 15/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 16/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 17/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 18/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 19/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 20/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 21/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 22/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 23/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 24/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 25/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 26/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 27/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 28/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 29/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 30/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 31/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 32/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 33/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 34/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 35/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 36/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 37/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 38/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 39/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 40/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 41/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 42/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 43/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 44/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 45/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 46/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 47/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 48/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 49/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 50/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 51/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 52/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 53/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 54/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 55/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 56/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 57/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 58/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 59/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 60/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 61/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 62/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 63/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 64/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 65/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 66/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 67/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 68/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 69/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 70/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 71/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 72/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 73/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 74/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 75/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 76/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 77/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 78/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 79/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 80/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 81/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 82/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 83/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 84/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 85/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 86/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 87/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 88/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 89/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 90/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 91/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 92/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 93/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 94/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 95/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 96/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 97/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 98/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 99/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091
# Epoch 100/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9091 - mse: 0.9091 - val_loss: 0.9091 - val_mse: 0.9091

# %%
plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), history.history['loss'], label='train loss')
plt.plot(range(N_EPOCHS), history.history['val_loss'], label='test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
