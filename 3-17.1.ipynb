# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

#regressor =LinearRegression()
#regressor.fit(X_train,y_train)


#y_pred =regressor.predict(X_test)

features = pd.read_csv("C:/Users/진현킴/downloads/Salary_Data.csv")

# %%
features
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
X=features.drop(["Salary"], axis=1)
X.head()
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2

# %%
Y=features[['Salary']]
Y.head()
# Out:
#     Salary
# 0  39343.0
# 1  46205.0
# 2  37731.0
# 3  43525.0
# 4  39891.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y,test_size=0.2,random_state=0)

# %%
regressor =LinearRegression()
regressor.fit(X_train,y_train)
accuracy_score =[]

y_pred =regressor.predict(X_test)
regressor.score(X_test,y_test)
# Out:
# 0.988169515729126

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
rsq = r2_score(y_test,y_pred)

# %%
print('Intercept of the model:',regressor.intercept_)
print('Coefficient of the line:',regressor.coef_)
# Out:
# Intercept of the model: [26780.09915063]
# Coefficient of the line: [[9312.57512673]]

# %%
plt.scatter(data = features,x = "Salary", y = "YearsExperience")
plt.xlabel('Salary')
plt.ylabel('YearsExperience')
plt.show()

# %%
features
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
print(regressor.coef_)
# Out:
# [[9312.57512673]]

# %%
plt.scatter(data = features,x = "Salary", y = "YearsExperience")
plt.xlabel('Salary')
plt.ylabel('YearsExperience')
plt.show()

# %%
sns.regplot(x=features["Salary"], 

           y=features["YearsExperience"], 

           fit_reg=True) # default

plt.title('prediction', fontsize=20)
# Out:
# Text(0.5, 1.0, 'prediction')
